# %%
# 下载cifar10
# PyTorch torchvision 下载 CIFAR-10 示例
from torchvision import datasets, transforms
import os

save_dir = './root/data'
os.makedirs(save_dir, exist_ok=True)

train = datasets.CIFAR10(root=save_dir, train=True, download=True)
test  = datasets.CIFAR10(root=save_dir, train=False, download=True)

print('Downloaded CIFAR-10 to', save_dir)
# Out:
# ...
# 100%|██████████| 170498071/170498071 [02:25<00:00, 1168828.39it/s]
# Extracting ./root/data/cifar-10-python.tar.gz to ./root/data
# Files already downloaded and verified
# Downloaded CIFAR-10 to ./root/data

# %%
# bash
python3 run.py --dataset cifar-10-10 --split_idx 3 --data_root ../root/data

# %%
#bash
python3 cgan.py --dataset cifar10 --split 3

# %%
# bash
python3 usps.py --dataset cifar10 --split 3
